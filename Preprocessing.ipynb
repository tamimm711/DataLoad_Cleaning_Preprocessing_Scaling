# %% [markdown]
# # Importing all the necessary libraries and api

# %%
import pandas as pd
import numpy as np
from pandas.api.types import is_numeric_dtype
from sklearn.preprocessing import OrdinalEncoder, LabelEncoder, OneHotEncoder,MinMaxScaler,StandardScaler,RobustScaler,MaxAbsScaler,FunctionTransformer
oe = OrdinalEncoder()
le = LabelEncoder()
ohe = OneHotEncoder(handle_unknown="ignore",sparse_output=False).set_output(transform="pandas")
min_max = MinMaxScaler(feature_range=(0, 1))
std = StandardScaler()
rb = RobustScaler()
maxabs = MaxAbsScaler()
ft = FunctionTransformer(np.log1p)
# "Import libraries and initialize common preprocessing tools"

# %% [markdown]
# # Loading the Data

# %%
DF = pd.read_excel("synthetic_health_dataset.xlsx") # "Loading the data"
DF
# Out:
#      Gender Smoking Alcohol_Consumption Exercise_Frequency Blood_Pressure  \
# 0    Female      No            Moderate              Never         Normal
# 1     Other     Yes                 NaN              Never         Normal
# 2      Male     Yes               Heavy              Daily           High
# 3      Male     Yes               Heavy              Daily         Normal
# 4      Male      No            Moderate              Often           High
# ..      ...     ...                 ...                ...            ...
# 995  Female      No               Heavy              Daily         Normal
# 996  Female      No               Heavy             Rarely         Normal
# 997  Female      No                 NaN             Rarely            NaN
# 998    Male     Yes               Heavy              Never           High
# 999    Male      No            Moderate             Rarely           High
#
#     Cholesterol_Level Stress_Level   Age   BMI  Heart_Rate  Sleep_Hours  \
# 0          Borderline         High  90.0  16.6       119.0          3.6
# 1              Normal          Low  20.0  29.9        69.0          9.9
# 2                High          Low  52.0  33.5        54.0          8.5
# 3                High          Low  15.0  20.3        72.0          9.5
# 4                High       Medium  60.0  36.0        58.0          4.4
# ..                ...          ...   ...   ...         ...          ...
# 995        Borderline       Medium  70.0  21.7        95.0          9.3
# 996        Borderline          Low  61.0  29.8        80.0          3.8
# 997              High          Low  40.0  33.0        81.0          4.2
# 998            Normal         High  94.0  38.5        81.0          6.0
# 999              High          Low  33.0  37.0         NaN          3.9
#
#      Blood_Sugar_Level Medication_Use Family_History Illness
# 0                143.6            NaN             No     Yes
# 1                121.8            NaN            Yes      No
# 2                107.0            NaN            Yes     Yes
# 3                 92.1            NaN             No     Yes
# 4                113.6            NaN             No     Yes
# ..                 ...            ...            ...     ...
# 995              187.6        Regular             No     Yes
# 996              114.3        Regular            Yes     Yes
# 997              119.0        Regular             No      No
# 998              187.8     Occasional            Yes      No
# 999              138.9            NaN            Yes     Yes
#
# [1000 rows x 15 columns]

# %% [markdown]
# # Cleaning the Data

# %%
DF.isna().sum() # Checking how many null value present in the data set
# Out:
# Gender                  12
# Smoking                  7
# Alcohol_Consumption    351
# Exercise_Frequency       7
# Blood_Pressure          10
# Cholesterol_Level        7
# Stress_Level             5
# Age                      8
# BMI                      6
# Heart_Rate               8
# Sleep_Hours              6
# Blood_Sugar_Level        3
# Medication_Use         345
# Family_History           5
# Illness                  0
# dtype: int64

# %%
DF.dropna(inplace=True) # "Removing null value and applying it at the same time"

# %%
DF.duplicated().sum() # Checking dupicated value
# Out:
# np.int64(0)

# %%
DF1 = DF.copy()
DF2 = DF.copy()
DF3 = DF.copy()
DF4 = DF.copy()
DF5 = DF.copy()
DF6 = DF.copy()
DF7 = DF.copy()
DF8 = DF.copy() # Making multiple copies of main data frame

# %%
# Applying LabelEncoder

# %%
for col in DF.columns:
    if not is_numeric_dtype(DF[col]):
        print(col) 

# Finding all the categorical columns
# Out:
# Gender
# Smoking
# Alcohol_Consumption
# Exercise_Frequency
# Blood_Pressure
# Cholesterol_Level
# Stress_Level
# Medication_Use
# Family_History
# Illness

# %%
DF1["Smoking"].unique() # Checking unique values
# Out:
# <StringArray>
# ['No', 'Yes']
# Length: 2, dtype: str

# %%
DF1["Smoking"] = le.fit_transform(DF1["Smoking"]) # Applying LabelEncoder

# %%
DF1["Family_History"].unique() # Checking unique values
# Out:
# <StringArray>
# ['No', 'Yes']
# Length: 2, dtype: str

# %%
DF1["Family_History"] = le.fit_transform(DF1["Family_History"]) # Applying LabelEncoder

# %% [markdown]
# # Applying OrdinalEncoder

# %%
DF1["Alcohol_Consumption"].unique() # Checking unique values
# Out:
# <StringArray>
# ['Moderate', 'Heavy']
# Length: 2, dtype: str

# %%
encoder = OrdinalEncoder(
    categories=[['Moderate', 'Heavy']])
DF1["Alcohol_Consumption"] = encoder.fit_transform(DF1[["Alcohol_Consumption"]])
# Encode the 'Alcohol_Consumption' column as ordinal values:
# 'Moderate' -> 0, 'Heavy' -> 1 (preserving the order of categories)

# %%
DF1["Exercise_Frequency"].unique() # Checking unique values
# Out:
# <StringArray>
# ['Never', 'Daily', 'Rarely', 'Often']
# Length: 4, dtype: str

# %%
encoder = OrdinalEncoder(
    categories=[['Never', 'Rarely', 'Often', 'Daily']])
DF1["Exercise_Frequency"] = encoder.fit_transform(DF1[["Exercise_Frequency"]])
# Encode 'Exercise_Frequency' as ordinal numeric values based on frequency level:
# Never -> 0, Rarely -> 1, Often -> 2, Daily -> 3

# %%
DF1["Blood_Pressure"].unique() # Checking unique values
# Out:
# <StringArray>
# ['High', 'Low', 'Normal']
# Length: 3, dtype: str

# %%
encoder1 = OrdinalEncoder(
    categories=[['Low', 'Normal', 'High']])
DF1["Blood_Pressure"] = encoder1.fit_transform(DF1[["Blood_Pressure"]])
# Encode 'Blood_Pressure' as ordinal numeric values by severity:
# Low -> 0, Normal -> 1, High -> 2

# %%
DF1["Cholesterol_Level"].unique() # Checking unique values
# Out:
# <StringArray>
# ['Borderline', 'Normal', 'High']
# Length: 3, dtype: str

# %%
encoder2 = OrdinalEncoder(
    categories=[['Normal', 'Borderline', 'High']])
DF1["Cholesterol_Level"] = encoder2.fit_transform(DF1[["Cholesterol_Level"]])
# Encode 'Cholesterol_Level' as ordinal numeric values by increasing risk:
# Normal -> 0, Borderline -> 1, High -> 2

# %%
DF1["Stress_Level"].unique() # Checking unique values
# Out:
# <StringArray>
# ['Medium', 'Low', 'High']
# Length: 3, dtype: str

# %%
encoder3 = OrdinalEncoder(
    categories=[['Low', 'Medium', 'High']])
DF1["Stress_Level"] = encoder3.fit_transform(DF1[["Stress_Level"]])
# Encode 'Stress_Level' as ordinal numeric values by intensity:
# Low -> 0, Medium -> 1, High -> 2

# %%
DF1["Medication_Use"].unique() # Checking unique values
# Out:
# <StringArray>
# ['Occasional', 'Regular']
# Length: 2, dtype: str

# %%
encoder4 = OrdinalEncoder(
    categories=[['Occasional', 'Regular']])
DF1["Medication_Use"] = encoder4.fit_transform(DF1[["Medication_Use"]])
# Encode 'Medication_Use' as ordinal numeric values by frequency:
# Occasional -> 0, Regular -> 1

# %% [markdown]
# # Applying OneHotEncoder

# %%
encode= ohe.fit_transform(DF1[["Gender"]]) # Apply One-Hot Encoding to 'Gender'

# %%
df1= pd.DataFrame(encode, columns=ohe.get_feature_names_out(["Gender"]))
# Create a DataFrame from the one-hot encoded Gender array
# and assign meaningful column names (e.g., Gender_Male, Gender_Female)

# %%
DF1 = pd.concat([DF1,df1], axis=1).drop(columns=["Gender"])
# Concatenate one-hot encoded Gender columns to DF1
# and drop the original 'Gender' column to avoid redundancy

# %%
DF1.head()
# Out:
#     Smoking  Alcohol_Consumption  Exercise_Frequency  Blood_Pressure  \
# 8         0                  0.0                 0.0             2.0
# 11        0                  0.0                 3.0             0.0
# 16        0                  0.0                 1.0             1.0
# 21        0                  1.0                 3.0             1.0
# 22        0                  0.0                 0.0             2.0
#
#     Cholesterol_Level  Stress_Level   Age   BMI  Heart_Rate  Sleep_Hours  \
# 8                 1.0           1.0  79.0  20.4        95.0          8.8
# 11                1.0           0.0  99.0  16.8        57.0          3.9
# 16                0.0           2.0  58.0  18.1        99.0          6.9
# 21                2.0           2.0  70.0  32.6        93.0          3.5
# 22                2.0           0.0  78.0  20.4        83.0          7.8
#
#     Blood_Sugar_Level  Medication_Use  Family_History Illness  Gender_Female  \
# 8                86.2             0.0               0     Yes            0.0
# 11              184.4             1.0               0     Yes            0.0
# 16              126.7             1.0               1      No            0.0
# 21              178.3             0.0               0     Yes            1.0
# 22              115.2             1.0               1      No            0.0
#
#     Gender_Male  Gender_Other
# 8           1.0           0.0
# 11          1.0           0.0
# 16          0.0           1.0
# 21          0.0           0.0
# 22          0.0           1.0

# %% [markdown]
# # Applying LabelEncoder with loop

# %%
binary_cols = ['Smoking', 'Family_History']

for col in binary_cols:
    DF2[col] = le.fit_transform(DF2[col])

# Apply Label Encoding to binary categorical columns

# %% [markdown]
# # Applying OrdinalEncoder with loop

# %%
ordinal_cols = ['Alcohol_Consumption','Exercise_Frequency','Blood_Pressure','Cholesterol_Level','Stress_Level','Medication_Use']

for col in ordinal_cols:
    DF2[col] = oe.fit_transform(DF2[[col]])

# Apply Ordinal Encoding to columns with natural order

# %% [markdown]
# # Applying OneHotEncoder with loop using dummy

# %%
categorical_cols = ['Gender']

for col in categorical_cols:
    dummy = pd.get_dummies(DF2[col],drop_first=True,prefix = col).astype("int64")
    DF2 = pd.concat([DF2, dummy], axis=1)
    DF2.drop(col, axis=1, inplace=True)
    
# Create dummy variables for categorical column 'Gender'
# drop_first=True avoids the dummy variable trap (multicollinearity)
# Add encoded columns to DF2 and remove the original column

# %%
DF2.head()
# Out:
#     Smoking  Alcohol_Consumption  Exercise_Frequency  Blood_Pressure  \
# 8         0                  1.0                 1.0             0.0
# 11        0                  1.0                 0.0             1.0
# 16        0                  1.0                 3.0             2.0
# 21        0                  0.0                 0.0             2.0
# 22        0                  1.0                 1.0             0.0
#
#     Cholesterol_Level  Stress_Level   Age   BMI  Heart_Rate  Sleep_Hours  \
# 8                 0.0           2.0  79.0  20.4        95.0          8.8
# 11                0.0           1.0  99.0  16.8        57.0          3.9
# 16                2.0           0.0  58.0  18.1        99.0          6.9
# 21                1.0           0.0  70.0  32.6        93.0          3.5
# 22                1.0           1.0  78.0  20.4        83.0          7.8
#
#     Blood_Sugar_Level  Medication_Use  Family_History Illness  Gender_Male  \
# 8                86.2             0.0               0     Yes            1
# 11              184.4             1.0               0     Yes            1
# 16              126.7             1.0               1      No            0
# 21              178.3             0.0               0     Yes            0
# 22              115.2             1.0               1      No            0
#
#     Gender_Other
# 8              0
# 11             0
# 16             1
# 21             0
# 22             1

# %% [markdown]
# # Min–Max Scaling

# %%
for col in DF.columns:
    if is_numeric_dtype(DF[col]):
        print(col)

# Loop through all columns and print names of numeric (int/float) columns
# Out:
# Age
# BMI
# Heart_Rate
# Sleep_Hours
# Blood_Sugar_Level

# %%
DF3.head()
# Out:
#     Gender Smoking Alcohol_Consumption Exercise_Frequency Blood_Pressure  \
# 8     Male      No            Moderate              Never           High
# 11    Male      No            Moderate              Daily            Low
# 16   Other      No            Moderate             Rarely         Normal
# 21  Female      No               Heavy              Daily         Normal
# 22   Other      No            Moderate              Never           High
#
#    Cholesterol_Level Stress_Level   Age   BMI  Heart_Rate  Sleep_Hours  \
# 8         Borderline       Medium  79.0  20.4        95.0          8.8
# 11        Borderline          Low  99.0  16.8        57.0          3.9
# 16            Normal         High  58.0  18.1        99.0          6.9
# 21              High         High  70.0  32.6        93.0          3.5
# 22              High          Low  78.0  20.4        83.0          7.8
#
#     Blood_Sugar_Level Medication_Use Family_History Illness
# 8                86.2     Occasional             No     Yes
# 11              184.4        Regular             No     Yes
# 16              126.7        Regular            Yes      No
# 21              178.3     Occasional             No     Yes
# 22              115.2        Regular            Yes      No

# %%
DF3["Age"]= min_max.fit_transform(DF3[["Age"]])
# Scale 'Age' to a normalized range (0–1) using Min-Max Scaling

# %%
DF3["BMI"]= min_max.fit_transform(DF3[["BMI"]])
# Scale 'BMI' to a normalized range (0–1) using Min-Max Scaling

# %%
DF3["Heart_Rate"]= min_max.fit_transform(DF3[["Heart_Rate"]])
# Scale 'BMI' to a normalized range (0–1) using Min-Max Scaling

# %%
DF3["Sleep_Hours"]= min_max.fit_transform(DF3[["Sleep_Hours"]])
# Scale 'Heart_Rate' to a normalized range (0–1) using Min-Max Scaling

# %%
DF3["Blood_Sugar_Level"]= min_max.fit_transform(DF3[["Blood_Sugar_Level"]])
# Scale 'Blood_Sugar_Level' to a normalized range (0–1) using Min-Max Scaling

# %%
DF3.head()
# Out:
#     Gender Smoking Alcohol_Consumption Exercise_Frequency Blood_Pressure  \
# 8     Male      No            Moderate              Never           High
# 11    Male      No            Moderate              Daily            Low
# 16   Other      No            Moderate             Rarely         Normal
# 21  Female      No               Heavy              Daily         Normal
# 22   Other      No            Moderate              Never           High
#
#    Cholesterol_Level Stress_Level       Age       BMI  Heart_Rate  \
# 8         Borderline       Medium  0.797980  0.210526    0.652174
# 11        Borderline          Low  1.000000  0.064777    0.101449
# 16            Normal         High  0.585859  0.117409    0.710145
# 21              High         High  0.707071  0.704453    0.623188
# 22              High          Low  0.787879  0.210526    0.478261
#
#     Sleep_Hours  Blood_Sugar_Level Medication_Use Family_History Illness
# 8      0.828571           0.123648     Occasional             No     Yes
# 11     0.128571           0.882535        Regular             No     Yes
# 16     0.557143           0.436631        Regular            Yes      No
# 21     0.071429           0.835394     Occasional             No     Yes
# 22     0.685714           0.347759        Regular            Yes      No

# %% [markdown]
# # Standardization Scaling

# %%
DF4.head()
# Out:
#     Gender Smoking Alcohol_Consumption Exercise_Frequency Blood_Pressure  \
# 8     Male      No            Moderate              Never           High
# 11    Male      No            Moderate              Daily            Low
# 16   Other      No            Moderate             Rarely         Normal
# 21  Female      No               Heavy              Daily         Normal
# 22   Other      No            Moderate              Never           High
#
#    Cholesterol_Level Stress_Level   Age   BMI  Heart_Rate  Sleep_Hours  \
# 8         Borderline       Medium  79.0  20.4        95.0          8.8
# 11        Borderline          Low  99.0  16.8        57.0          3.9
# 16            Normal         High  58.0  18.1        99.0          6.9
# 21              High         High  70.0  32.6        93.0          3.5
# 22              High          Low  78.0  20.4        83.0          7.8
#
#     Blood_Sugar_Level Medication_Use Family_History Illness
# 8                86.2     Occasional             No     Yes
# 11              184.4        Regular             No     Yes
# 16              126.7        Regular            Yes      No
# 21              178.3     Occasional             No     Yes
# 22              115.2        Regular            Yes      No

# %%
for col in DF.columns:
    if is_numeric_dtype(DF[col]):
        print(col)

# Loop through all columns and print names of numeric (int/float) columns
# Out:
# Age
# BMI
# Heart_Rate
# Sleep_Hours
# Blood_Sugar_Level

# %%
DF4["Age"]= std.fit_transform(DF4[["Age"]])
# Standardize using StandardScaler

# %%
DF4["BMI"]= std.fit_transform(DF4[["BMI"]])
# Standardize using StandardScaler

# %%
DF4["Heart_Rate"]= std.fit_transform(DF4[["Heart_Rate"]])
# Standardize using StandardScaler

# %%
DF4["Sleep_Hours"]= std.fit_transform(DF4[["Sleep_Hours"]])
# Standardize using StandardScaler

# %%
DF4["Blood_Sugar_Level"]= std.fit_transform(DF4[["Blood_Sugar_Level"]])
# Standardize using StandardScaler

# %%
DF4.head()
# Out:
#     Gender Smoking Alcohol_Consumption Exercise_Frequency Blood_Pressure  \
# 8     Male      No            Moderate              Never           High
# 11    Male      No            Moderate              Daily            Low
# 16   Other      No            Moderate             Rarely         Normal
# 21  Female      No               Heavy              Daily         Normal
# 22   Other      No            Moderate              Never           High
#
#    Cholesterol_Level Stress_Level       Age       BMI  Heart_Rate  \
# 8         Borderline       Medium  1.034589 -0.934544    0.494317
# 11        Borderline          Low  1.716659 -1.429377   -1.363395
# 16            Normal         High  0.318415 -1.250687    0.689866
# 21              High         High  0.727657  0.742388    0.396543
# 22              High          Low  1.000485 -0.934544   -0.092329
#
#     Sleep_Hours  Blood_Sugar_Level Medication_Use Family_History Illness
# 8      1.036195          -1.354719     Occasional             No     Yes
# 11    -1.333877           1.269922        Regular             No     Yes
# 16     0.117187          -0.272255        Regular            Yes      No
# 21    -1.527353           1.106884     Occasional             No     Yes
# 22     0.552507          -0.579621        Regular            Yes      No

# %% [markdown]
# # Robust Scaling

# %%
DF5.head()
# Out:
#     Gender Smoking Alcohol_Consumption Exercise_Frequency Blood_Pressure  \
# 8     Male      No            Moderate              Never           High
# 11    Male      No            Moderate              Daily            Low
# 16   Other      No            Moderate             Rarely         Normal
# 21  Female      No               Heavy              Daily         Normal
# 22   Other      No            Moderate              Never           High
#
#    Cholesterol_Level Stress_Level   Age   BMI  Heart_Rate  Sleep_Hours  \
# 8         Borderline       Medium  79.0  20.4        95.0          8.8
# 11        Borderline          Low  99.0  16.8        57.0          3.9
# 16            Normal         High  58.0  18.1        99.0          6.9
# 21              High         High  70.0  32.6        93.0          3.5
# 22              High          Low  78.0  20.4        83.0          7.8
#
#     Blood_Sugar_Level Medication_Use Family_History Illness
# 8                86.2     Occasional             No     Yes
# 11              184.4        Regular             No     Yes
# 16              126.7        Regular            Yes      No
# 21              178.3     Occasional             No     Yes
# 22              115.2        Regular            Yes      No

# %%
for col in DF.columns:
    if is_numeric_dtype(DF[col]):
        print(col)

# Loop through all columns and print names of numeric (int/float) columns
# Out:
# Age
# BMI
# Heart_Rate
# Sleep_Hours
# Blood_Sugar_Level

# %%
DF5["Age"]= rb.fit_transform(DF5[["Age"]])
# Scale using RobustScaler

# %%
DF5["BMI"]= rb.fit_transform(DF5[["BMI"]])
# Scale using RobustScaler

# %%
DF5["Heart_Rate"]= rb.fit_transform(DF5[["Heart_Rate"]])
# Scale using RobustScaler

# %%
DF5["Sleep_Hours"]= rb.fit_transform(DF5[["Sleep_Hours"]])
# Scale using RobustScaler

# %%
DF5["Blood_Sugar_Level"]= rb.fit_transform(DF5[["Blood_Sugar_Level"]])
# Scale using RobustScaler

# %%
DF5.head()
# Out:
#     Gender Smoking Alcohol_Consumption Exercise_Frequency Blood_Pressure  \
# 8     Male      No            Moderate              Never           High
# 11    Male      No            Moderate              Daily            Low
# 16   Other      No            Moderate             Rarely         Normal
# 21  Female      No               Heavy              Daily         Normal
# 22   Other      No            Moderate              Never           High
#
#    Cholesterol_Level Stress_Level       Age       BMI  Heart_Rate  \
# 8         Borderline       Medium  0.596154 -0.479087    0.314286
# 11        Borderline          Low  0.980769 -0.752852   -0.771429
# 16            Normal         High  0.192308 -0.653992    0.428571
# 21              High         High  0.423077  0.448669    0.257143
# 22              High          Low  0.576923 -0.479087   -0.028571
#
#     Sleep_Hours  Blood_Sugar_Level Medication_Use Family_History Illness
# 8      0.542857          -0.820472     Occasional             No     Yes
# 11    -0.857143           0.725984        Regular             No     Yes
# 16     0.000000          -0.182677        Regular            Yes      No
# 21    -0.971429           0.629921     Occasional             No     Yes
# 22     0.257143          -0.363780        Regular            Yes      No

# %% [markdown]
# # Max Absolute Scaling

# %%
DF6.head()
# Out:
#     Gender Smoking Alcohol_Consumption Exercise_Frequency Blood_Pressure  \
# 8     Male      No            Moderate              Never           High
# 11    Male      No            Moderate              Daily            Low
# 16   Other      No            Moderate             Rarely         Normal
# 21  Female      No               Heavy              Daily         Normal
# 22   Other      No            Moderate              Never           High
#
#    Cholesterol_Level Stress_Level   Age   BMI  Heart_Rate  Sleep_Hours  \
# 8         Borderline       Medium  79.0  20.4        95.0          8.8
# 11        Borderline          Low  99.0  16.8        57.0          3.9
# 16            Normal         High  58.0  18.1        99.0          6.9
# 21              High         High  70.0  32.6        93.0          3.5
# 22              High          Low  78.0  20.4        83.0          7.8
#
#     Blood_Sugar_Level Medication_Use Family_History Illness
# 8                86.2     Occasional             No     Yes
# 11              184.4        Regular             No     Yes
# 16              126.7        Regular            Yes      No
# 21              178.3     Occasional             No     Yes
# 22              115.2        Regular            Yes      No

# %%
for col in DF.columns:
    if is_numeric_dtype(DF[col]):
        print(col)

# Loop through all columns and print names of numeric (int/float) columns
# Out:
# Age
# BMI
# Heart_Rate
# Sleep_Hours
# Blood_Sugar_Level

# %%
DF6["Age"]= maxabs.fit_transform(DF6[["Age"]])
# Scale using MaxAbsScaler

# %%
DF6["BMI"]= maxabs.fit_transform(DF6[["BMI"]])
# Scale using MaxAbsScaler

# %%
DF6["Heart_Rate"]= maxabs.fit_transform(DF6[["Heart_Rate"]])
# Scale using MaxAbsScaler

# %%
DF6["Sleep_Hours"]= maxabs.fit_transform(DF6[["Sleep_Hours"]])
# Scale using MaxAbsScaler

# %%
DF6["Blood_Sugar_Level"]= maxabs.fit_transform(DF6[["Blood_Sugar_Level"]])
# Scale using MaxAbsScaler

# %%
DF6.head()
# Out:
#     Gender Smoking Alcohol_Consumption Exercise_Frequency Blood_Pressure  \
# 8     Male      No            Moderate              Never           High
# 11    Male      No            Moderate              Daily            Low
# 16   Other      No            Moderate             Rarely         Normal
# 21  Female      No               Heavy              Daily         Normal
# 22   Other      No            Moderate              Never           High
#
#    Cholesterol_Level Stress_Level       Age       BMI  Heart_Rate  \
# 8         Borderline       Medium  0.797980  0.511278    0.798319
# 11        Borderline          Low  1.000000  0.421053    0.478992
# 16            Normal         High  0.585859  0.453634    0.831933
# 21              High         High  0.707071  0.817043    0.781513
# 22              High          Low  0.787879  0.511278    0.697479
#
#     Sleep_Hours  Blood_Sugar_Level Medication_Use Family_History Illness
# 8          0.88           0.431864     Occasional             No     Yes
# 11         0.39           0.923848        Regular             No     Yes
# 16         0.69           0.634770        Regular            Yes      No
# 21         0.35           0.893287     Occasional             No     Yes
# 22         0.78           0.577154        Regular            Yes      No
